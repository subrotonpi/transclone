# %%
import pandas as pd

# %%
fi
# Out:
#           id                                               code
# 0          5  public static void main ( String input ) {\n  ...
# 1          6  public static int N ( ) {\n  int N = Integer ....
# 2          7  public static int N ( ) {\n  String [ ] W = in...
# 3          8  import java.io.OutputStream;\nimport java.io.I...
# 4         10  public static void input ( ) {\n  System . out...
# ...      ...                                                ...
# 48801  76213  @ result static int searchNotLargeThan ( int x...
# 48802  76215  @ String ( filename = "C-large-2.in" ) public ...
# 48803  76217  static final int reverse ( int n ) throws IOEx...
# 48804  76219  static final Scanner getScanner ( final Scanne...
# 48805  17532
#
# [48806 rows x 2 columns]

# %%
f
# Out:
#           id                                               code
# 0          5  public static void main ( String input ) {\n  ...
# 1          6  public static int N ( ) {\n  int N = Integer ....
# 2          7  public static int N ( ) {\n  String [ ] W = in...
# 3          8  import java.io.OutputStream;\nimport java.io.I...
# 4         10  public static void input ( ) {\n  System . out...
# ...      ...                                                ...
# 48801  76213  @ result static int searchNotLargeThan ( int x...
# 48802  76215  @ String ( filename = "C-large-2.in" ) public ...
# 48803  76217  static final int reverse ( int n ) throws IOEx...
# 48804  76219  static final Scanner getScanner ( final Scanne...
# 48805  17532
#
# [48806 rows x 2 columns]
